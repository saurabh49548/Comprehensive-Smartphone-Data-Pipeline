# %% [markdown]
# <a href="https://colab.research.google.com/github/saurabh49548/Comprehensive-Smartphone-Data-Pipeline/blob/main/WebScraping_ExtractingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('/content/smartBricks.html', encoding='utf-8') as f:
  html= f.read()

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
soup = BeautifulSoup(html,'lxml')

# %%
soup.prettify()
# Out:
# '<html class="way-item-finder sm-smc-in" lang="en" style="--window-width: 1536;">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width" name="viewport"/>\n  <title>\n   Mobile Phones In Stock | Smartprix\n  </title>\n  <link href="/sm-32x32.png" rel="icon" sizes="32x32" type="image/png"/>\n  <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>\n  <meta content="#0a3a75" name="theme-color"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <meta content="app-id=1142915507" name="apple-itunes-app"/>\n  <meta content="171761809591603" property="fb:app_id"/>\n  <link href="https://www.smartprix.com/mobiles/exclude_out_of_stock-exclude_upcoming-stock" rel="canonical"/>\n  <meta content="en_IN" property="og:locale"/>\n  <meta content="Smartprix" property="og:site_name"/>\n  <meta content="@smartprix" name="twitter:site"/>\n  <meta content="@smartprix" name="twitter:creator"/>\n  <meta content="summary" name="twitter:card"/>\n  <link href="/smart
# ...

# %%
container=soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})  #Since this whole structure is a list

# %%
len(soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}))   #No. of phones
# Out:
# 1019

# %%
for i in container:
  print(i.find('h2').text)
  print(i.find('span',{'class':'price'}).text)
# Out:
# Oppo F31 Pro 5G
# ₹26,999
# Oppo F31 Pro Plus 5G
# ₹32,999
# Oppo F31 5G
# ₹22,999
# OPPO Reno 13 5G
# ₹26,999
# Apple iPhone 17
# ₹82,900
# Vivo T4 Pro 5G
# ₹27,782
# Samsung Galaxy S24 FE 5G
# ₹34,782
# Motorola Moto G86 Power 5G
# ₹17,710
# OnePlus Nord CE 5 5G
# ₹24,997
# Motorola Edge 60 Pro
# ₹28,332
# Apple iPhone 17 Pro Max
# ₹1,49,900
# Samsung Galaxy S24 Ultra
# ₹81,499
# Motorola Edge 60 Fusion
# ₹22,245
# Samsung Galaxy A17 5G
# ₹18,999
# Motorola Moto G96 5G
# ₹17,769
# Xiaomi Redmi Note 14 SE 5G
# ₹13,999
# Vivo V60 5G
# ₹36,999
# OnePlus Nord 5 5G
# ₹31,998
# Google Pixel 9
# ₹51,360
# Samsung Galaxy F17 5G
# ₹14,499
# OPPO Reno 14 5G
# ₹37,998
# Apple iPhone 16
# ₹69,499
# Vivo T4x 5G
# ₹13,999
# Xiaomi Redmi Note 13 Pro Plus 5G
# ₹17,994
# Vivo X200 FE
# ₹54,998
# Samsung Galaxy S24 5G
# ₹49,450
# Vivo T4R 5G
# ₹19,499
# Oppo K13
# ₹17,068
# Realme 15T 5G
# ₹20,999
# Oppo F31 Pro 5G (12GB RAM + 256GB)
# ₹30,999
# Nothing Phone 3 5G
# ₹44,899
# iQOO Neo 10R
# ₹24,999
# ...

# %%
for i in container:
  #print(i.find('h2').text)
  #print(i.find('span',{'class':'price'}).text)
  print(i.find('div',{'class':'score rank-1-bg'}))
# Out:
# <div class="score rank-1-bg"><b>81</b><small>Spec Score</small></div>
# <div class="score rank-1-bg"><b>82</b><small>Spec Score</small></div>
# None
# <div class="score rank-1-bg"><b>85</b><small>Spec Score</small></div>
# None
# <div class="score rank-1-bg"><b>82</b><small>Spec Score</small></div>
# <div class="score rank-1-bg"><b>84</b><small>Spec Score</small></div>
# <div class="score rank-1-bg"><b>83</b><small>Spec Score</small></div>
# <div class="score rank-1-bg"><b>83</b><small>Spec Score</small></div>
# <div class="score rank-1-bg"><b>80</b><small>Spec Score</small></div>
# <div class="score rank-1-bg"><b>82</b><small>Spec Score</small></div>
# <div class="score rank-1-bg"><b>92</b><small>Spec Score</small></div>
# <div class="score rank-1-bg"><b>84</b><small>Spec Score</small></div>
# None
# <div class="score rank-1-bg"><b>80</b><small>Spec Score</small></div>
# <div class="score rank-1-bg"><b>81</b><small>Spec Score</small></div>
# ...

# %% [markdown]
# It has some none also and extracting b tag value will give error at some place --> Dealing with these type of situation we have try and catch

# %%
for i in container:
    print(i.find('div',{'class':'score rank-1-bg'}).find('b'))
# Out:
# <b>81</b>
# <b>82</b>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1386659150.py in <cell line: 0>()
#       1 for i in container:
# ----> 2   print(i.find('div',{'class':'score rank-1-bg'}).find('b'))
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
for i in container:
  try:
    print(i.find('div',{'class':'score rank-1-bg'}).find('b').text)
  except:
    print(np.nan)
# Out:
# 81
# 82
# nan
# 85
# nan
# 82
# 84
# 83
# 83
# 80
# 82
# 92
# 84
# nan
# 80
# 81
# 86
# 84
# 87
# nan
# 86
# 85
# nan
# 84
# 89
# 86
# 80
# nan
# 82
# 82
# 90
# 81
# nan
# nan
# nan
# nan
# 88
# 93
# 83
# 83
# 81
# 83
# 89
# 87
# 82
# 81
# 90
# 84
# 87
# 83
# 82
# nan
# 80
# nan
# 85
# nan
# nan
# 86
# nan
# 81
# 83
# 83
# 87
# 87
# nan
# 86
# 84
# nan
# 80
# nan
# 89
# 84
# 81
# 80
# nan
# 89
# 81
# 83
# 86
# nan
# nan
# 85
# 89
# 81
# 82
# 85
# 85
# 83
# 89
# 85
# 81
# 83
# nan
# nan
# 83
# 95
# 81
# 81
# nan
# 80
# nan
# nan
# 83
# nan
# nan
# 83
# nan
# nan
# 91
# 82
# nan
# 80
# 87
# nan
# 88
# 80
# 80
# 81
# 82
# nan
# nan
# 87
# nan
# 88
# nan
# nan
# 83
# 86
# 82
# 85
# 85
# nan
# nan
# 83
# 83
# 86
# nan
# nan
# nan
# nan
# 82
# nan
# 83
# nan
# nan
# 83
# nan
# 84
# 86
# 85
# 83
# 84
# nan
# 84
# 84
# nan
# nan
# 84
# 88
# nan
# 84
# 83
# nan
# 82
# 82
# 81
# nan
# 90
# nan
# nan
# 90
# nan
# 84
# 82
# 87
# 87
# nan
# 85
# 82
# 90
# 86
# 93
# nan
# 81
# nan
# 87
# nan
# 83
# ...

# %%
name=[]
price=[]
specs=[]
for i in container:
  name.append(i.find('h2').text)
  price.append(i.find('span',{'class':'price'}).text)
  try:
    specs.append(i.find('div',{'class':'score rank-1-bg'}).find('b').text)
  except:
    specs.append(np.nan)

# %%
len(name)
# Out:
# 1019

# %%
len(price)
# Out:
# 1019

# %%
df=pd.DataFrame({
    'model':name,
    'price':price,
    'rating':specs
})

# %%
df
# Out:
#                                  model    price rating
# 0                      Oppo F31 Pro 5G  ₹26,999     81
# 1                 Oppo F31 Pro Plus 5G  ₹32,999     82
# 2                          Oppo F31 5G  ₹22,999    NaN
# 3                      OPPO Reno 13 5G  ₹26,999     85
# 4                      Apple iPhone 17  ₹82,900    NaN
# ...                                ...      ...    ...
# 1014  Lava Blaze Duo (8GB RAM + 128GB)  ₹15,999    NaN
# 1015                          Amaq Q20   ₹1,199    NaN
# 1016             Jio Bharat Karbonn K2     ₹975    NaN
# 1017     Samsung Galaxy Z Flip 7 FE 5G  ₹84,999     89
# 1018                     Karbonn K444r   ₹1,259    NaN
#
# [1019 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# model       0
# price       0
# rating    465
# dtype: int64

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)

    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')  #As all below are in the ul
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                                  model    price rating  \
# 0                      Oppo F31 Pro 5G  ₹26,999    NaN
# 1                 Oppo F31 Pro Plus 5G  ₹32,999    NaN
# 2                          Oppo F31 5G  ₹22,999     78
# 3                      OPPO Reno 13 5G  ₹26,999    NaN
# 4                      Apple iPhone 17  ₹82,900     78
# ...                                ...      ...    ...
# 1014  Lava Blaze Duo (8GB RAM + 128GB)  ₹15,999     79
# 1015                          Amaq Q20   ₹1,199    NaN
# 1016             Jio Bharat Karbonn K2     ₹975    NaN
# 1017     Samsung Galaxy Z Flip 7 FE 5G  ₹84,999    NaN
# 1018                     Karbonn K444r   ₹1,259    NaN
#
#                                                     sim  \
# 0                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 3     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1019 entries, 0 to 1018
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1019 non-null   object
#  1   price      1019 non-null   object
#  2   rating     360 non-null    object
#  3   sim        1019 non-null   object
#  4   processor  1019 non-null   object
#  5   ram        1019 non-null   object
#  6   battery    1019 non-null   object
#  7   display    1019 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1009 non-null   object
#  10  os         985 non-null    object
# dtypes: object(11)
# memory usage: 87.7+ KB

# %%
df.to_csv('Uncleaned_Smartphon.csv')
