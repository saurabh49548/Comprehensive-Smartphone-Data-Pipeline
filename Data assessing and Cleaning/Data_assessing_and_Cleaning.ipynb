# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('/content/Uncleaned_Smartphon.csv')

# %% [markdown]
# #  **Data Assessing**

# %% [markdown]
# > `Summary of the Dataset :`
#
#
# * I collected a dataset of 1,019 smartphone entries from Smartprix Website through web scraping. Each row represents a phone model and includes 12 columns covering different specifications such as model name, price, rating, SIM type, processor, RAM, battery, display, camera, storage card option, and operating system.
# * The dataset has some issues — such as mixed text formats, missing brand names, and inconsistent values — which need to be cleaned and organized before analysis.

# %% [markdown]
# **`Manual Assessment`**
#
#
# ---
#
#
# 1. **Quality Issue:**
#     1. **model**- some brands are written differently like OPPO in model column `consistency issue`
#     2. **price**- has unneccesary 'â‚¹'. `validity issue`
#     3. **price**- has ',' between numbers `validity issue`
#     5. **ratings**- missing values `completeness issue`
#     6. **processor**- has some incorrect value for some phones(row #- 412,433,462,509,513,521,530,550,552,560,561,617,638,684,729,743,750,756,758,779,822,837,838,842,860,894,925,932,935,936,942,963,977,989,1002,1012,1018) `validity issue`
#         * Row# 486 has value in ram col `validity issue`
#     7. **ram**- Some rows have incorrect value(row# 213, 513,514,445,462,514,521,550,560,617,638,729,743,750,758,759,838,840,860,894,925,932,942,952,953,967,968,989,994,1002,1004,1011,1018) `validity issue`
#     8. **battery**-
#         * Sometimes charging info is not given `completeness issue`
#         * Some rows has incorrect value(row# 145,412,433,445,462,485,486,509,513,521,530,550,552,560,617,638,684,729,743,750,758,838,860,894,919,925,925,935,936,939,952,953,963,967,968,977,989,994,1002,1004,1011,1018,1020.) `validity issue`
#
#     9. **display**-
#         * Sometimes freq info is not given `completeness issue`
#         * Incorrect value in(row# 6,145,355,412,433,445,462,521,550,560,617,638,729,743,750,758,838,860,894,925,935,936,939,942,952,953,967,968,977,989,1002,1011,1012,1018) `validity issue`
#
#     10. Certain Phones are foldable and this info is scattered `validity issue`
#     11. **camera**- words like Dual,Triple,Quad are used to represent no. of cameras and front and rear cameras are seprated by '&' `Not an issue just an obsevation`
#         * Many rows have incorrect value(Row# 6,145,199,217,306,404,405,412,427,433,437,445,462,492,511,513,518,530,550,552,560,569,571,582,601,609,617,638,666,675,694,701,729,735,743,750,838,860,894,898,899,916,919,925,939,951,952,953,967,968,989,994,1002,1004,1010,1011,1017,1018,1019) `validity issue`
#     12. **card**- sometimes contains info about os and camera `validity issue`
#     13. **os**- sometimes contains info bluetooth and fm radio `validity issue`
#         * Sometimes contains os version name like 'Android v8.1 (Oreo)' `consistency issue`
#     14. Missing value in card,os and rating `completeness issue`
#     15. Data type of price and rating is incorrect. `validiy issue`
#
# 2. **Tidiness Issue:**
#     1. **sim**- can be split 3 cols has_5g,has_NFC,has_IR_Blaster
#       2. **ram**- can be split into 3 cols RAM and ROM
#       3. **processor** - can be split into processor_name,core and CPU speed.
#       4. **batery**- can be split into battery capacity, fast_charging_available
#       5. **display**- can be split into size,resolution_width,resolution_height and frequency.
#       6. **camera**- can be split into front and rear camera
#       7. **card**- can be split into supported and extended_upto
#
# 3. One of the major problem with the data which we have scrape is the shifting of some rows.

# %% [markdown]
# **`Programatic Assessment`**
#
#
# ---
#
# Right now our data is too much unclean, So we can't be able to do much Programatic assessment.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1019 entries, 0 to 1018
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1019 non-null   int64
#  1   model       1019 non-null   object
#  2   price       1019 non-null   object
#  3   rating      360 non-null    float64
#  4   sim         1019 non-null   object
#  5   processor   1019 non-null   object
#  6   ram         1019 non-null   object
#  7   battery     1019 non-null   object
#  8   display     1019 non-null   object
#  9   camera      1019 non-null   object
#  10  card        1009 non-null   object
#  11  os          985 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 95.7+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0      rating
# count  1019.000000  360.000000
# mean    509.000000   73.472222
# std     294.304264    5.313493
# min       0.000000   54.000000
# 25%     254.500000   71.000000
# 50%     509.000000   74.000000
# 75%     763.500000   77.000000
# max    1018.000000   79.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Once we do a basic level of asssesment than programming assisment will help us more better.

# %% [markdown]
# Here, for this DataSet we do the iterative approach. We'll do one level of assessment then one level of cleaning then assessment then cleaning....nd so on.

# %% [markdown]
# # **Data Cleaning**
# ### `Working with Data Quality Issue(Dirty Data)`

# %%
#Make a copy
df1=df.copy()

# %% [markdown]
# By order of sevirity, we first go with completeness issue but right now we are not in a situation to do work with completeness issue (fill data etc). So we will go with the 2nd order in sevirity that is validity issue.

# %%
#Define- #Replace all the 'â‚¹' and ',' with ''. Also change its data type to int
#Code
df1['price']=df1['price'].str.replace('â‚¹','').str.replace('₹','').str.replace(',','').astype(int)

# %%
#Test
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1019 entries, 0 to 1018
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1019 non-null   int64
#  1   model       1019 non-null   object
#  2   price       1019 non-null   int64
#  3   rating      360 non-null    float64
#  4   sim         1019 non-null   object
#  5   processor   1019 non-null   object
#  6   ram         1019 non-null   object
#  7   battery     1019 non-null   object
#  8   display     1019 non-null   object
#  9   camera      1019 non-null   object
#  10  card        1009 non-null   object
#  11  os          985 non-null    object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 95.7+ KB

# %%
df1.head()
# Out:
#    Unnamed: 0                 model  price  rating  \
# 0           0       Oppo F31 Pro 5G  26999     NaN
# 1           1  Oppo F31 Pro Plus 5G  32999     NaN
# 2           2           Oppo F31 5G  22999    78.0
# 3           3       OPPO Reno 13 5G  26999     NaN
# 4           4       Apple iPhone 17  82900    78.0
#
#                                                  sim  \
# 0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 3  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 4            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                            processor  \
# 0  Dimensity 7300 Energy, Octa Core, 2.5 GHz Proc...
# 1   Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor
# 2       Dimensity 6300, Octa Core, 2.4 GHz Processor
# 3      Dimensity 8350, Octa Core, 3.35 GHz Processor
# 4                     Apple A19, Hexa Core Processor
#
# ...

# %%
df1=df1.reset_index()

# %%
df1.drop('Unnamed: 0',axis=1,inplace=True)

# %%
#Aligning the index column of our data frame with excel sheet so that the row numbers in the assessment match.(As we have listed row no. from the sheet)
df1['index']=df1['index']+2

# %%
df1
# Out:
#       index                             model  price  rating  \
# 0         2                   Oppo F31 Pro 5G  26999     NaN
# 1         3              Oppo F31 Pro Plus 5G  32999     NaN
# 2         4                       Oppo F31 5G  22999    78.0
# 3         5                   OPPO Reno 13 5G  26999     NaN
# 4         6                   Apple iPhone 17  82900    78.0
# ...     ...                               ...    ...     ...
# 1014   1016  Lava Blaze Duo (8GB RAM + 128GB)  15999    79.0
# 1015   1017                          Amaq Q20   1199     NaN
# 1016   1018             Jio Bharat Karbonn K2    975     NaN
# 1017   1019     Samsung Galaxy Z Flip 7 FE 5G  84999     NaN
# 1018   1020                     Karbonn K444r   1259     NaN
#
#                                                     sim  \
# 0                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# ...

# %%
processor_row=set((412,433,462,509,513,521,530,550,552,560,561,617,638,684,729,743,750,756,758,779,822,837,838,842,860,894,925,932,935,936,942,963,977,989,1002,1012,1018))
ram_row=set((213, 513,514,445,462,514,521,550,560,617,638,729,743,750,758,759,838,840,860,894,925,932,942,952,953,967,968,989,994,1002,1004,1011,1018))
battery_row=set((145,412,433,445,462,485,486,509,513,521,530,550,552,560,617,638,684,729,743,750,758,838,860,894,919,925,925,935,936,939,952,953,963,967,968,977,989,994,1002,1004,1011,1018,1020))
display_row=set((6,145,355,412,433,445,462,521,550,560,617,638,729,743,750,758,838,860,894,925,935,936,939,942,952,953,967,968,977,989,1002,1011,1012,1018))
camera_row=set((6,145,199,217,306,404,405,412,427,433,437,445,462,492,511,513,518,530,550,552,560,569,571,582,601,609,617,638,666,675,694,701,729,735,743,750,838,860,894,898,899,916,919,925,939,951,952,953,967,968,989,994,1002,1004,1010,1011,1017,1018,1019))

# %%
df1[df1['index'].isin(processor_row | ram_row | battery_row | display_row | camera_row)]  #Taking union
#These are those rows in which there is atleast one problem in any col
#Total 87 rows out of 1019 rows
# Out:
#       index                          model   price  rating  \
# 4         6                Apple iPhone 17   82900    78.0
# 143     145        Apple iPhone 17 (512GB)  102900    79.0
# 197     199        Samsung Galaxy Z Fold 7  174999     NaN
# 211     213           Apple iPhone 16 Plus   78999     NaN
# 215     217            Motorola Razr 60 5G   40660     NaN
# ...     ...                            ...     ...     ...
# 1010   1012                  Karbonn K101i     880     NaN
# 1015   1017                       Amaq Q20    1199     NaN
# 1016   1018          Jio Bharat Karbonn K2     975     NaN
# 1017   1019  Samsung Galaxy Z Flip 7 FE 5G   84999     NaN
# 1018   1020                  Karbonn K444r    1259     NaN
#
#                                                 sim  \
# 4           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 143         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 197   Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# ...

# %%
df1[df1['index'].isin(processor_row & ram_row & battery_row & display_row & camera_row)]  #intersection
#rows in which all col have problem
#Total 15 rows
# Out:
#       index                      model  price  rating  \
# 460     462           Jio Bharat J1 4G   1799     NaN
# 548     550        Nokia 5310 Dual Sim   3399     NaN
# 558     560         Motorola Moto A200   1119     NaN
# 615     617            Nokia 2660 Flip   4499     NaN
# 636     638             Lava Action 4G   1649     NaN
# 727     729         Samsung Guru E1200    774     NaN
# 741     743       HMD 150 Music (2025)   2149     NaN
# 748     750                 Amaq Q1 4G   2498     NaN
# 836     838      Jio Bharat K1 Karbonn    890     NaN
# 858     860             Lava Gem Power   1539     NaN
# 892     894          Motorola Moto A70   1699     NaN
# 923     925  Nokia 105 Dual SIM (2019)    977     NaN
# 987     989                Jmax Gold 2    649     NaN
# 1000   1002                   iKall I6    899     NaN
# 1016   1018      Jio Bharat Karbonn K2    975     NaN
#
#                             sim                 processor  \
# ...

# %%
#observation
df1[df1['index'].isin(processor_row & ram_row & battery_row & display_row & camera_row)]['price'].mean()
# Out:
# np.float64(1700.9333333333334)

# %% [markdown]
# * Observation:
#   * In our Dataset mostle problemetic rows are those which are cheaper, (less then 2000)
#   * Also mostly these phones are not smartphone they are feature/keypad phone.
# * Our main goal is to do the EDA for the smartphones not keypad phone,So we can drop those rows.

# %%
df1=df1[df1['price']>3000]    #Based on our observation there is no smartphone below 3500
df1
# Out:
#       index                             model  price  rating  \
# 0         2                   Oppo F31 Pro 5G  26999     NaN
# 1         3              Oppo F31 Pro Plus 5G  32999     NaN
# 2         4                       Oppo F31 5G  22999    78.0
# 3         5                   OPPO Reno 13 5G  26999     NaN
# 4         6                   Apple iPhone 17  82900    78.0
# ...     ...                               ...    ...     ...
# 1006   1008                   Lava Yuva Smart   5899    61.0
# 1007   1009     itel Zeno 10 (4GB RAM + 64GB)   6499    56.0
# 1011   1013       Vivo Y29 5G (8GB RAM+256GB)  18999    78.0
# 1014   1016  Lava Blaze Duo (8GB RAM + 128GB)  15999    79.0
# 1017   1019     Samsung Galaxy Z Flip 7 FE 5G  84999     NaN
#
#                                                     sim  \
# 0                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# ...

# %%
df1[df1['index'].isin(processor_row & ram_row & battery_row & display_row & camera_row)]
# Out:
#      index                model  price  rating               sim  \
# 548    550  Nokia 5310 Dual Sim   3399     NaN          Dual Sim
# 615    617      Nokia 2660 Flip   4499     NaN  Dual Sim, 3G, 4G
#
#                    processor               ram  \
# 548  8 MB RAM, 16 MB inbuilt  1200 mAh Battery
# 615                  No Wifi       Unisoc T107
#
#                               battery             display  \
# 548  2.4 inches, 240 x 320 px Display  0.3 MP Rear Camera
# 615         48 MB RAM, 128 MB inbuilt    1450 mAh Battery
#
#                                 camera          card                  os
# 548  Memory Card Supported, upto 32 GB     Bluetooth             Browser
# 615   2.8 inches, 240 x 320 px Display  Dual Display  0.3 MP Rear Camera

# %% [markdown]
# > **Working with Processor column**:

# %%
#Define
df1[df1['index'].isin(processor_row)] #Rows with problem in processor col
# Out:
#      index                 model  price  rating                      sim  \
# 431    433     Nokia 235 4G 2024   4069     NaN  Dual Sim, 3G, 4G, VoLTE
# 519    521  Nokia 3210 4G (2024)   3749     NaN         Dual Sim, 3G, 4G
# 548    550   Nokia 5310 Dual Sim   3399     NaN                 Dual Sim
# 615    617       Nokia 2660 Flip   4499     NaN         Dual Sim, 3G, 4G
#
#                    processor                           ram  \
# 431                  No Wifi  Unisoc T107, 1 GHz Processor
# 519                  No Wifi  Unisoc T107, 1 GHz Processor
# 548  8 MB RAM, 16 MB inbuilt              1200 mAh Battery
# 615                  No Wifi                   Unisoc T107
#
#                               battery             display  \
# 431         64 MB RAM, 128 MB inbuilt    1450 mAh Battery
# 519         64 MB RAM, 128 MB inbuilt    1450 mAh Battery
# 548  2.4 inches, 240 x 320 px Display  0.3 MP Rear Camera
# 615         48 MB RAM, 128 MB inbuilt    1450 mAh Battery
#
# ...

# %% [markdown]
# Although we can do shifting but after checking our internet about these phones, we get to know that these are feature phone not smartphone. So we will remove them.

# %%
#code
df1.drop([431,519,615],inplace=True)
# Out:
# /tmp/ipython-input-2174722559.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop([431,519,615],inplace=True)

# %%
#test
df1[df1['index'].isin(processor_row)]
# Out:
#      index                model  price  rating       sim  \
# 548    550  Nokia 5310 Dual Sim   3399     NaN  Dual Sim
#
#                    processor               ram  \
# 548  8 MB RAM, 16 MB inbuilt  1200 mAh Battery
#
#                               battery             display  \
# 548  2.4 inches, 240 x 320 px Display  0.3 MP Rear Camera
#
#                                 camera       card       os
# 548  Memory Card Supported, upto 32 GB  Bluetooth  Browser

# %% [markdown]
# > **Working with ram column:**

# %%
df1[df1['index'].isin(ram_row)]
# Out:
#      index                         model   price  rating  \
# 211    213          Apple iPhone 16 Plus   78999     NaN
# 512    514  Apple iPhone 16 Plus (256GB)   89900     NaN
# 548    550           Nokia 5310 Dual Sim    3399     NaN
# 757    759  Apple iPhone 16 Plus (512GB)  105900     NaN
#
#                                          sim  \
# 211  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 512  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 548                                 Dual Sim
# 757  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                      processor               ram  \
# 211  Bionic A18, Hexa Core, 4.04 GHz Processor    128 GB inbuilt
# 512  Bionic A18, Hexa Core, 4.04 GHz Processor    256 GB inbuilt
# 548                    8 MB RAM, 16 MB inbuilt  1200 mAh Battery
# 757  Bionic A18, Hexa Core, 4.04 GHz Processor    512 GB inbuilt
#
#                                  battery  \
# 211  4674 mAh Battery with Fast Charging
# ...

# %% [markdown]
# Here only ROM is given not RAm

# %% [markdown]
# > **Working with battery column**:

# %%
temp_df=df1[df1['index'].isin(battery_row)]

# %%
temp_df
# Out:
#      index                    model   price  rating  \
# 143    145  Apple iPhone 17 (512GB)  102900    79.0
# 548    550      Nokia 5310 Dual Sim    3399     NaN
# 917    919  Apple iPhone 12 (256GB)   63999    76.0
#
#                                          sim  \
# 143  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 548                                 Dual Sim
# 917  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                     processor                       ram  \
# 143            Apple A19, Hexa Core Processor  8 GB RAM, 512 GB inbuilt
# 548                   8 MB RAM, 16 MB inbuilt          1200 mAh Battery
# 917  Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
#
#                                                battery  \
# 143  6.3 inches, 1206 x 2622 px, 120 Hz Display wit...
# 548                   2.4 inches, 240 x 320 px Display
# 917  6.1 inches, 1170 x 2532 px Display with Large ...
#
# ...

# %% [markdown]
# Define- We required to do the shifting of rows - shift(axis=1) func of pandas will be used

# %%
#code
x=temp_df.iloc[::2,7:].shift(1,axis=1)
x
# Out:
#     battery                                            display  \
# 143    None  6.3 inches, 1206 x 2622 px, 120 Hz Display wit...
# 917    None  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                            camera                       card  \
# 143  48 MP + 48 MP Dual Rear & 18 MP Front Camera  Memory Card Not Supported
# 917  12 MP + 12 MP Dual Rear & 12 MP Front Camera  Memory Card Not Supported
#
#           os
# 143  iOS v26
# 917  iOS v14

# %%
y=temp_df.iloc[1::2,6:].shift(1,axis=1)
y
# Out:
#       ram           battery                           display  \
# 548  None  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                  camera                               card         os
# 548  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB  Bluetooth

# %% [markdown]
# Now we have to do this edting in the original DataFrame

# %%
df1.loc[temp_df.index,temp_df.columns[7:]]= x
df1.loc[y.index,y.columns]=y

# %%
#test
df1[df1['index'].isin(battery_row)]
# Out:
#      index                    model   price  rating  \
# 143    145  Apple iPhone 17 (512GB)  102900    79.0
# 548    550      Nokia 5310 Dual Sim    3399     NaN
# 917    919  Apple iPhone 12 (256GB)   63999    76.0
#
#                                          sim  \
# 143  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 548                                 Dual Sim
# 917  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                     processor                       ram  \
# 143            Apple A19, Hexa Core Processor  8 GB RAM, 512 GB inbuilt
# 548                   8 MB RAM, 16 MB inbuilt                      None
# 917  Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
#
#               battery                                            display  \
# 143              None  6.3 inches, 1206 x 2622 px, 120 Hz Display wit...
# 548  1200 mAh Battery                   2.4 inches, 240 x 320 px Display
# ...

# %% [markdown]
# > **Working with display cols**

# %%
df1[df1['index'].isin(display_row)]  #there is no problem
# Out:
#      index                    model   price  rating  \
# 4        6          Apple iPhone 17   82900    78.0
# 143    145  Apple iPhone 17 (512GB)  102900    79.0
# 548    550      Nokia 5310 Dual Sim    3399     NaN
#
#                                          sim                       processor  \
# 4    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Apple A19, Hexa Core Processor
# 143  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Apple A19, Hexa Core Processor
# 548                                 Dual Sim         8 MB RAM, 16 MB inbuilt
#
#                           ram  \
# 4    8 GB RAM, 256 GB inbuilt
# 143  8 GB RAM, 512 GB inbuilt
# 548                      None
#
#                                                battery  \
# 4    6.3 inches, 1206 x 2622 px, 120 Hz Display wit...
# 143                                               None
# 548                                   1200 mAh Battery
#
#                                                display  \
# ...

# %% [markdown]
# > **Working with camera column**:

# %%
temp_df2=df1[df1['index'].isin(camera_row)]
temp_df2
# Out:
#       index                                         model   price  rating  \
# 4         6                               Apple iPhone 17   82900    78.0
# 143     145                       Apple iPhone 17 (512GB)  102900    79.0
# 197     199                       Samsung Galaxy Z Fold 7  174999     NaN
# 215     217                           Motorola Razr 60 5G   40660     NaN
# 304     306      Samsung Galaxy Z Fold 7 (16GB RAM + 1TB)  216999     NaN
# 402     404                        Motorola Razr 50 Ultra   57930     NaN
# 403     405                                Lava Agni 3 5G   16999     NaN
# 425     427                        Motorola Razr 60 Ultra   89998     NaN
# 435     437                       Samsung Galaxy Z Fold 6  112998     NaN
# 490     492    Samsung Galaxy Z Fold 7 (12GB RAM + 512GB)  179999     NaN
# 509     511                              Vivo X Fold 5 5G  149998     NaN
# 516     518                       Google Pixel 9 Pro Fold  137999     NaN
# ...

# %%
#Define- Shifting the 4th index row towards right from battery col
#code
z=temp_df2.iloc[0:1,7:].shift(1,axis=1)
z
# Out:
#   battery                                            display  \
# 4    None  6.3 inches, 1206 x 2622 px, 120 Hz Display wit...
#
#                                          camera                       card  \
# 4  48 MP + 48 MP Dual Rear & 18 MP Front Camera  Memory Card Not Supported
#
#         os
# 4  iOS v26

# %%
#Assigning it to the original dataframe
df1.loc[z.index,z.columns]=z

# %%
#Test
df1
# Out:
#       index                             model  price  rating  \
# 0         2                   Oppo F31 Pro 5G  26999     NaN
# 1         3              Oppo F31 Pro Plus 5G  32999     NaN
# 2         4                       Oppo F31 5G  22999    78.0
# 3         5                   OPPO Reno 13 5G  26999     NaN
# 4         6                   Apple iPhone 17  82900    78.0
# ...     ...                               ...    ...     ...
# 1006   1008                   Lava Yuva Smart   5899    61.0
# 1007   1009     itel Zeno 10 (4GB RAM + 64GB)   6499    56.0
# 1011   1013       Vivo Y29 5G (8GB RAM+256GB)  18999    78.0
# 1014   1016  Lava Blaze Duo (8GB RAM + 128GB)  15999    79.0
# 1017   1019     Samsung Galaxy Z Flip 7 FE 5G  84999     NaN
#
#                                                     sim  \
# 0                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# ...

# %%
#Rows with no problem in camera section
temp_df2[temp_df2['camera'].str.contains('MP')]
# Out:
#      index                    model   price  rating  \
# 4        6          Apple iPhone 17   82900    78.0
# 143    145  Apple iPhone 17 (512GB)  102900    79.0
# 548    550      Nokia 5310 Dual Sim    3399     NaN
# 917    919  Apple iPhone 12 (256GB)   63999    76.0
#
#                                          sim  \
# 4    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 143  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 548                                 Dual Sim
# 917  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                     processor                       ram  \
# 4              Apple A19, Hexa Core Processor  8 GB RAM, 256 GB inbuilt
# 143            Apple A19, Hexa Core Processor  8 GB RAM, 512 GB inbuilt
# 548                   8 MB RAM, 16 MB inbuilt                      None
# 917  Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
#
#               battery                                            display  \
# ...

# %%
temp_df2[temp_df2['camera'].str.contains('MP')].shape
# Out:
# (4, 12)

# %%
#Smartphones with problem in camera
temp_df2[~temp_df2['camera'].str.contains('MP')].shape
# Out:
# (25, 12)

# %%
temp_df2=temp_df2[~temp_df2['camera'].str.contains('MP')]

# %%
temp_df2
# Out:
#       index                                         model   price  rating  \
# 197     199                       Samsung Galaxy Z Fold 7  174999     NaN
# 215     217                           Motorola Razr 60 5G   40660     NaN
# 304     306      Samsung Galaxy Z Fold 7 (16GB RAM + 1TB)  216999     NaN
# 402     404                        Motorola Razr 50 Ultra   57930     NaN
# 403     405                                Lava Agni 3 5G   16999     NaN
# 425     427                        Motorola Razr 60 Ultra   89998     NaN
# 435     437                       Samsung Galaxy Z Fold 6  112998     NaN
# 490     492    Samsung Galaxy Z Fold 7 (12GB RAM + 512GB)  179999     NaN
# 509     511                              Vivo X Fold 5 5G  149998     NaN
# 516     518                       Google Pixel 9 Pro Fold  137999     NaN
# 567     569                                Lava Blaze Duo   14999    77.0
# 569     571              Lava Agni 3 5G (8GB RAM + 256GB)   20999     NaN
# ...

# %%
#Define- In df1, we have to put the value of card column in camera column from temp_df2
#code
df1.loc[temp_df2.index,'camera']=temp_df2['card'].values

# %%
#test
df1[df1['index'].isin(camera_row)]
# Out:
#       index                                         model   price  rating  \
# 4         6                               Apple iPhone 17   82900    78.0
# 143     145                       Apple iPhone 17 (512GB)  102900    79.0
# 197     199                       Samsung Galaxy Z Fold 7  174999     NaN
# 215     217                           Motorola Razr 60 5G   40660     NaN
# 304     306      Samsung Galaxy Z Fold 7 (16GB RAM + 1TB)  216999     NaN
# 402     404                        Motorola Razr 50 Ultra   57930     NaN
# 403     405                                Lava Agni 3 5G   16999     NaN
# 425     427                        Motorola Razr 60 Ultra   89998     NaN
# 435     437                       Samsung Galaxy Z Fold 6  112998     NaN
# 490     492    Samsung Galaxy Z Fold 7 (12GB RAM + 512GB)  179999     NaN
# 509     511                              Vivo X Fold 5 5G  149998     NaN
# 516     518                       Google Pixel 9 Pro Fold  137999     NaN
# ...

# %%
pd.set_option('display.max_rows',None)   #To see all the rows without trunctation
df['camera'].value_counts()
# Out:
# camera
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                             74
# 50 MP + 2 MP Dual Rear & 16 MP Front Camera                            53
# 0.3 MP Rear Camera                                                     42
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera                            33
# 50 MP + 2 MP Dual Rear & 32 MP Front Camera                            26
# Foldable Display, Dual Display                                         24
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                   22
# 50 MP + 8 MP Dual Rear & 32 MP Front Camera                            21
# 50 MP + 5 MP + 2 MP Triple Rear & 13 MP Front Camera                   21
# 50 MP + 50 MP + 8 MP Triple Rear & 32 MP Front Camera                  19
# 50 MP + 8 MP + 2 MP Triple Rear & 13 MP Front Camera                   18
# 50 MP + 8 MP Dual Rear & 50 MP Front Camera                            18
# 50 MP + 50 MP + 8 MP Triple Rear & 50 MP Front Camera                  16
# ...

# %% [markdown]
# > **Working with card column:**

# %%
#Programatic assessment
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported                                                  184
# Memory Card (Hybrid), upto 1 TB                                            159
# Android v15                                                                119
# Android v14                                                                 83
# Memory Card Supported, upto 1 TB                                            78
# Memory Card (Hybrid), upto 2 TB                                             62
# Memory Card (Hybrid)                                                        43
# Android v12                                                                 30
# Memory Card Supported, upto 2 TB                                            26
# Android v13                                                                 24
# Memory Card Supported                                                       20
# Memory Card Supported, upto 512 GB                                          19
# ...

# %%
#Define- Replacing the camera value in card column with 'Memory Card Not Supported'
#code
temp_df3=df1[df1['card'].str.contains('MP')]
temp_df3
# Out:
#       index                                         model   price  rating  \
# 197     199                       Samsung Galaxy Z Fold 7  174999     NaN
# 215     217                           Motorola Razr 60 5G   40660     NaN
# 304     306      Samsung Galaxy Z Fold 7 (16GB RAM + 1TB)  216999     NaN
# 402     404                        Motorola Razr 50 Ultra   57930     NaN
# 403     405                                Lava Agni 3 5G   16999     NaN
# 425     427                        Motorola Razr 60 Ultra   89998     NaN
# 435     437                       Samsung Galaxy Z Fold 6  112998     NaN
# 490     492    Samsung Galaxy Z Fold 7 (12GB RAM + 512GB)  179999     NaN
# 509     511                              Vivo X Fold 5 5G  149998     NaN
# 516     518                       Google Pixel 9 Pro Fold  137999     NaN
# 567     569                                Lava Blaze Duo   14999    77.0
# 569     571              Lava Agni 3 5G (8GB RAM + 256GB)   20999     NaN
# ...

# %%
df1.loc[temp_df3.index,'card']='Memory card not supported'

# %%
#Test
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported             184
# Memory Card (Hybrid), upto 1 TB       159
# Android v15                           119
# Android v14                            83
# Memory Card Supported, upto 1 TB       78
# Memory Card (Hybrid), upto 2 TB        62
# Memory Card (Hybrid)                   43
# Android v12                            30
# Memory card not supported              28
# Memory Card Supported, upto 2 TB       26
# Android v13                            24
# Memory Card Supported                  20
# Memory Card Supported, upto 512 GB     19
# Memory Card (Hybrid), upto 1.5 TB      14
# Android v11                             9
# Memory Card Supported, upto 256 GB      5
# Memory Card (Hybrid), upto 256 GB       4
# Android v10                             4
# Android v16                             3
# Memory Card Supported, upto 32 GB       2
# Memory Card Supported, upto 128 GB      2
# Android v10.1                           1
# ...

# %%
#Rows with defect value in card column
temp_df=df1[~df1['card'].str.contains('Memory')]
# Out:
#      index                                           model   price  rating  \
# 0        2                                 Oppo F31 Pro 5G   26999     NaN
# 1        3                            Oppo F31 Pro Plus 5G   32999     NaN
# 2        4                                     Oppo F31 5G   22999    78.0
# 3        5                                 OPPO Reno 13 5G   26999     NaN
# 5        7                                  Vivo T4 Pro 5G   27782     NaN
# 9       11                            Motorola Edge 60 Pro   28332     NaN
# 17      19                               OnePlus Nord 5 5G   31998     NaN
# 18      20                                  Google Pixel 9   51360     NaN
# 20      22                                 OPPO Reno 14 5G   37998     NaN
# 25      27                           Samsung Galaxy S24 5G   49450     NaN
# 27      29                                        Oppo K13   17068    78.0
# ...

# %%
#define- Putting the value of card column in os column
#code
df1.loc[temp_df.index,'os']=temp_df['card'].values

# %%
#test
df1['os'].value_counts()
# Out:
# os
# Android v14                  314
# Android v15                  308
# Android v13                  104
# Android v12                   67
# Android v11                   38
# Memory Card Not Supported     19
# iOS v18                       15
# iOS v26                       12
# Android v10                    9
# Android v16                    6
# iOS v17                        4
# Android v9.0 (Pie)             4
# Android v8.1 (Oreo)            3
# iOS v16                        3
# iOS v15                        2
# Android 14 Go Edition          2
# Android v10.0                  1
# Android 15 Go                  1
# iOS v13                        1
# Bluetooth                      1
# Android v10.1                  1
# KAI OS                         1
# S30+                           1
# iOS v14                        1
# Android v7.1.2 (Nougat)        1
# iOS v11                        1
# Name: count, dtype: int64

# %%
#define- Replacing the rows with not word 'memory' in card cols with 'Memory Card Not Supported'
#code
df1.loc[temp_df.index,'card']='Memory Card Not Supported'

# %%
#test
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported             457
# Memory Card (Hybrid), upto 1 TB       159
# Memory Card Supported, upto 1 TB       78
# Memory Card (Hybrid), upto 2 TB        62
# Memory Card (Hybrid)                   43
# Memory card not supported              28
# Memory Card Supported, upto 2 TB       26
# Memory Card Supported                  20
# Memory Card Supported, upto 512 GB     19
# Memory Card (Hybrid), upto 1.5 TB      14
# Memory Card Supported, upto 256 GB      5
# Memory Card (Hybrid), upto 256 GB       4
# Memory Card Supported, upto 32 GB       2
# Memory Card Supported, upto 128 GB      2
# Memory Card (Hybrid), upto 128 GB       1
# Name: count, dtype: int64

# %% [markdown]
# > **Working with os column**:

# %%
df1['os'].value_counts()
# Out:
# os
# Android v14                  314
# Android v15                  308
# Android v13                  104
# Android v12                   67
# Android v11                   38
# Memory Card Not Supported     19
# iOS v18                       15
# iOS v26                       12
# Android v10                    9
# Android v16                    6
# iOS v17                        4
# Android v9.0 (Pie)             4
# Android v8.1 (Oreo)            3
# iOS v16                        3
# iOS v15                        2
# Android 14 Go Edition          2
# Android v10.0                  1
# Android 15 Go                  1
# iOS v13                        1
# Bluetooth                      1
# Android v10.1                  1
# KAI OS                         1
# S30+                           1
# iOS v14                        1
# Android v7.1.2 (Nougat)        1
# iOS v11                        1
# Name: count, dtype: int64

# %%
temp_df=temp_df = df1[df1['os'].str.contains('Memory|Bluetooth',na=False)]     #df1[df1['os'].str.contains('Memory'|'Bluetooth')] does a bitwise OR between strings, which isn’t valid.
                                                                               #na=False avoids errors if there are NaN values in the column

# %%
#Define-Replacing rows with 'Memory' and 'Bluetooth' in os section with nan value
#code
df1.loc[temp_df.index,'os']=np.nan

# %%
#test
df1['os'].value_counts()
# Out:
# os
# Android v14                314
# Android v15                308
# Android v13                104
# Android v12                 67
# Android v11                 38
# iOS v18                     15
# iOS v26                     12
# Android v10                  9
# Android v16                  6
# iOS v17                      4
# Android v9.0 (Pie)           4
# iOS v16                      3
# Android v8.1 (Oreo)          3
# iOS v15                      2
# Android 14 Go Edition        2
# Android 15 Go                1
# iOS v13                      1
# Android v10.0                1
# Android v10.1                1
# KAI OS                       1
# S30+                         1
# iOS v14                      1
# Android v7.1.2 (Nougat)      1
# iOS v11                      1
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %%
df1['camera'].value_counts()
# Out:
# camera
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                                 74
# 50 MP + 2 MP Dual Rear & 16 MP Front Camera                                53
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera                                33
# 50 MP + 2 MP Dual Rear & 32 MP Front Camera                                26
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                       22
# 50 MP + 5 MP + 2 MP Triple Rear & 13 MP Front Camera                       21
# 50 MP + 8 MP Dual Rear & 32 MP Front Camera                                21
# 50 MP + 50 MP + 8 MP Triple Rear & 32 MP Front Camera                      19
# 50 MP + 8 MP + 2 MP Triple Rear & 13 MP Front Camera                       18
# 50 MP + 8 MP Dual Rear & 50 MP Front Camera                                18
# 50 MP + 50 MP Dual Rear & 50 MP Front Camera                               16
# 50 MP + 50 MP + 8 MP Triple Rear & 50 MP Front Camera                      16
# ...

# %%
df1['sim'].value_counts()
# Out:
# sim
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           288
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      201
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster          106
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster               103
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi                                65
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC                 58
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC, IR Blaster     30
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster                    28
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi                      21
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR Blaster           6
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                            5
# Dual Sim, 3G, 4G, Wi-Fi                                        5
# Dual Sim                                                       2
# Single Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC                1
# ...

# %%
df1['processor'].value_counts()
# Out:
# processor
# Dimensity 6300, Octa Core, 2.4 GHz Processor                    104
# Dimensity 7300, Octa Core, 2.5 GHz Processor                     24
# Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor                  24
# Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor                 23
# Snapdragon 8s Gen3, Octa Core, 3 GHz Processor                   18
# Snapdragon 7s Gen3, Octa Core, 2.5 GHz Processor                 18
# Snapdragon 695, Octa Core, 2.2 GHz Processor                     17
# Exynos 1380, Octa Core, 2.4 GHz Processor                        17
# Snapdragon 7s Gen2, Octa Core, 2.4 GHz Processor                 15
# Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor                  15
# Dimensity 6100 Plus, Octa Core, 2.2 GHz Processor                15
# Snapdragon 6 Gen1, Octa Core, 2.2 GHz Processor                  13
# Dimensity 7400, Octa Core, 2.6 GHz Processor                     13
# Dimensity 7050, Octa Core, 2.6 GHz Processor                     12
# ...

# %%
df1['display'].value_counts()
# Out:
# display
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole          74
# 6.77 inches, 1080 x 2392 px, 120 Hz Display with Punch Hole          48
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole           42
# 6.67 inches, 720 x 1604 px, 120 Hz Display with Punch Hole           28
# 6.78 inches, 1260 x 2800 px, 120 Hz Display with Punch Hole          21
# 6.67 inches, 1220 x 2712 px, 120 Hz Display with Punch Hole          21
# 6.78 inches, 1264 x 2780 px, 120 Hz Display with Punch Hole          18
# 6.74 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch      16
# 6.67 inches, 720 x 1600 px, 120 Hz Display with Punch Hole           15
# 6.72 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole          14
# 6.83 inches, 1272 x 2800 px, 120 Hz Display with Punch Hole          14
# 6.72 inches, 1080 x 2408 px, 120 Hz Display with Punch Hole          14
# 6.7 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole           11
# ...
